# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns  # Change alias to 'sns'
import numpy as np
import pandas as pd

sns.set()  # Use 'sns'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate random multivariate normal data
data = np.random.multivariate_normal(mean=[0, 0], cov=[[5, 2], [2, 5]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])

# Plot histograms for each column
for col in 'xy':
    plt.hist(data[col], density=True, alpha=0.5, label=col)

# Add labels and legend
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
data = np.random.multivariate_normal([0,0], [[5,2], [2,2]], size=2000)
data = pd.DataFrame(data,columns=['x', 'y',])

for col in 'xy':
    plt.hist(data[col], density=True, alpha=0.5)

# %%
sns.kdeplot(data=data, x='x', y='y');

# %%
import seaborn as sns

# KDE plot with the updated parameter
sns.kdeplot(data=data, fill=True)
plt.show()

# %%
sns.kdeplot(data=data, x='x', y='y');

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species', height=2.5);

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Assuming `tips` DataFrame is already loaded, e.g., using sns.load_dataset("tips")
tips = sns.load_dataset("tips")

# Add a calculated column for percentage of the tip
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']

# Create the FacetGrid
grid = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15))
plt.show()

# %%
with sns.axes_style(style='ticks'):
    g = sns.catplot(x='day', y='total_bill', hue='sex', data=tips, kind='box')
    g.set_axis_labels("Day", "Total Bill")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the 'tips' dataset
tips = sns.load_dataset("tips")

# Create the joint plot with the correct data argument
with sns.axes_style('white'):
    sns.jointplot(x="total_bill", y="tip", data=tips, kind="hex")

plt.show()

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind='reg');

# %%
planets = sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
with sns.axes_style('white'):
    g = sns.catplot(x='year', data=planets, aspect=2, 
                   kind="count", color='steelblue')
    g.set_xticklabels(step=5)

# %%
with sns.axes_style('white'):
    g = sns.catplot(x="year", data=planets, aspect=4.0, kind="count",
                   hue="method", order=range(2001, 2015))
    g.set_ylabels('Number of Planets Discovered')

# %%
import pandas as pd

# Correct URL for the dataset
url = "https://raw.githubusercontent.com/jakevdp/marathon-data/master/marathon-data.csv"

# Load the dataset
data = pd.read_csv(url)

# Display the first few rows
data.head()
# Out:
#    age gender     split     final
# 0   33      M  01:05:38  02:08:51
# 1   32      M  01:06:26  02:09:28
# 2   31      M  01:06:49  02:10:42
# 3   38      M  01:06:16  02:13:45
# 4   31      M  01:06:32  02:13:59

# %%
data.dtypes
# Out:
# age        int64
# gender    object
# split     object
# final     object
# dtype: object

# %%
import pandas as pd
import datetime

def convert_time(s):
    # Directly handle the split and convert to timedelta
    h, m, s = map(int, s.split(':'))  # Fix the typo in 'splot'
    return datetime.timedelta(hours=h, minutes=m, seconds=s)

# Use 'converters' argument to apply the conversion to 'split' and 'final' columns
url = "https://raw.githubusercontent.com/jakevdp/marathon-data/master/marathon-data.csv"
data = pd.read_csv(url, converters={'split': convert_time, 'final': convert_time})

# Display the first few rows
data.head()
# Out:
#    age gender           split           final
# 0   33      M 0 days 01:05:38 0 days 02:08:51
# 1   32      M 0 days 01:06:26 0 days 02:09:28
# 2   31      M 0 days 01:06:49 0 days 02:10:42
# 3   38      M 0 days 01:06:16 0 days 02:13:45
# 4   31      M 0 days 01:06:32 0 days 02:13:59

# %%
data.dtypes
# Out:
# age                 int64
# gender             object
# split     timedelta64[ns]
# final     timedelta64[ns]
# dtype: object

# %%
data['split_sec']=data['split']
data['split_sec']=data['split']
data
# Out:
#        age gender           split           final       split_sec
# 0       33      M 0 days 01:05:38 0 days 02:08:51 0 days 01:05:38
# 1       32      M 0 days 01:06:26 0 days 02:09:28 0 days 01:06:26
# 2       31      M 0 days 01:06:49 0 days 02:10:42 0 days 01:06:49
# 3       38      M 0 days 01:06:16 0 days 02:13:45 0 days 01:06:16
# 4       31      M 0 days 01:06:32 0 days 02:13:59 0 days 01:06:32
# ...    ...    ...             ...             ...             ...
# 37245   18      M 0 days 04:24:24 0 days 09:32:57 0 days 04:24:24
# 37246   36      M 0 days 04:35:43 0 days 09:33:28 0 days 04:35:43
# 37247   51      M 0 days 04:22:35 0 days 09:33:40 0 days 04:22:35
# 37248   55      W 0 days 04:58:06 0 days 10:00:40 0 days 04:58:06
# 37249   58      W 0 days 04:59:49 0 days 10:01:08 0 days 04:59:49
#
# [37250 rows x 5 columns]

# %%
data.dtypes
# Out:
# age                    int64
# gender                object
# split        timedelta64[ns]
# final        timedelta64[ns]
# split_sec    timedelta64[ns]
# dtype: object

# %%
data['split_sec'] = data['split'].astype('timedelta64[s]').astype(int) / 1E9
data['final_sec'] = data['final'].astype('timedelta64[s]').astype(int) / 1E9
data.head()
# Out:
#    age gender           split           final  split_sec  final_sec  \
# 0   33      M 0 days 01:05:38 0 days 02:08:51   0.000004   0.000008
# 1   32      M 0 days 01:06:26 0 days 02:09:28   0.000004   0.000008
# 2   31      M 0 days 01:06:49 0 days 02:10:42   0.000004   0.000008
# 3   38      M 0 days 01:06:16 0 days 02:13:45   0.000004   0.000008
# 4   31      M 0 days 01:06:32 0 days 02:13:59   0.000004   0.000008
#
#    split_frac
# 0   -0.018756
# 1   -0.026262
# 2   -0.022443
# 3    0.009097
# 4    0.006842

# %%
with sns.axes_style('white'):
    g = sns.jointplot(x='split_sec', y = 'final_sec', data=data, kind='hex')
    g.ax_joint.plot(np.linspace(4000,16000),np.linspace(4000,32000),':k')

# %%
data['split_frac'] = 1 - 2 * data['split_sec']/data['final_sec']
data.head()
# Out:
#    age gender           split           final  split_sec  final_sec  \
# 0   33      M 0 days 01:05:38 0 days 02:08:51   0.000004   0.000008
# 1   32      M 0 days 01:06:26 0 days 02:09:28   0.000004   0.000008
# 2   31      M 0 days 01:06:49 0 days 02:10:42   0.000004   0.000008
# 3   38      M 0 days 01:06:16 0 days 02:13:45   0.000004   0.000008
# 4   31      M 0 days 01:06:32 0 days 02:13:59   0.000004   0.000008
#
#    split_frac
# 0   -0.018756
# 1   -0.026262
# 2   -0.022443
# 3    0.009097
# 4    0.006842

# %%
sns.displot(data['split_frac'], kde=False)
plt.axvline(0, color='k', linestyle='--');

# %%
sum(data.split_frac<0)
# Out:
# 251

# %%
g = sns.PairGrid(data, vars=['age','split_sec', 'final_sec', 'split_frac'], hue='gender', palette='RdBu_r')
g.map(plt.scatter, alpha=0.8)
g.add_legend();

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Ensure data is filtered correctly for 'M' and 'W' genders, and handle missing values if necessary
men_data = data[data['gender'] == 'M']['split_frac']
women_data = data[data['gender'] == 'W']['split_frac']

# Create KDE plots for men and women, using fill=True instead of shade
sns.kdeplot(men_data, label='Men', fill=True)
sns.kdeplot(women_data, label='Women', fill=True)

# Set plot labels and title
plt.xlabel('split_frac')
plt.title('KDE of split_frac by Gender')

# Show the legend
plt.legend()

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the violin plot with corrected usage of hue and palette
sns.violinplot(x='gender', y='split_frac', data=data, hue='gender', palette=['lightblue', 'lightpink'], legend=False)

# Set plot labels and title
plt.xlabel('Gender')
plt.ylabel('Split Fraction')
plt.title('Violin Plot of Split Fraction by Gender')

# Show the plot
plt.show()

# %%
data['age_dec'] = data.age.map(lambda age: 10 * (age // 10))
data.head()
# Out:
#    age gender           split           final  split_sec  final_sec  \
# 0   33      M 0 days 01:05:38 0 days 02:08:51   0.000004   0.000008
# 1   32      M 0 days 01:06:26 0 days 02:09:28   0.000004   0.000008
# 2   31      M 0 days 01:06:49 0 days 02:10:42   0.000004   0.000008
# 3   38      M 0 days 01:06:16 0 days 02:13:45   0.000004   0.000008
# 4   31      M 0 days 01:06:32 0 days 02:13:59   0.000004   0.000008
#
#    split_frac  age_dec
# 0   -0.018756       30
# 1   -0.026262       30
# 2   -0.022443       30
# 3    0.009097       30
# 4    0.006842       30

# %%
men = (data.gender == 'M')
women = (data.gender == 'W')

with sns.axes_style(style=None):
    sns.violinplot(x="age_dec", y='split_frac', hue='gender', data=data, split=True, inner='quartile', palette=['lightblue', 'lightpink'], legend=False);

# %%
(data.age > 80).sum()
# Out:
# np.int64(7)

# %%
g = sns.lmplot(x='final_sec', y='split_frac', col='gender', data=data, markers=',', scatter_kws=dict(color='c'))
g.map(plt.axhline, y=0.0, color='k', ls=':');

# %%
pip install holoviews
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 3.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 23.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 MB 26.7 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.0.11/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bokeh
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.0.11/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import holoviews as hv
from holoviews import opts
hv.extension('bokeh', 'matplotlib')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='02e2929e-d93b-4ed6-ae17-d6a1b6e57b67'>
#   <div id="c17d5e94-0622-47df-be43-9f210b8fae3e" data-root-id="02e2929e-d93b-4ed6-ae17-d6a1b6e57b67" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
import pandas as pd

gender_degree_data = pd.read_csv("https://datasets.holoviz.org/bachelor_women/v1/percent_bachelors_degrees_women_usa.csv")

title = ('Percentage of Bachelor\'s degrees conferred to women in '
        'the U.S.A. by major (1970-2011)\n')

# These are the colors that will be used in the plot
color_sequence = ['#1f77b4', '#aec7e8', '#ff7f0e', '#ffbb78', '#2ca02c',
                  '#98df8a', '#d62728', '#ff9896', '#9467bd', '#c5b0d5',
                  '#8c564b', '#c49c94', '#e377c2', '#f7b6d2', '#7f7f7f',
                  '#c7c7c7', '#bcbd22', '#dbdb8d', '#17becf', '#9edae5']

# Offsets for degree labels
y_offsets = {'Foreign Languages': 0.5, 'English': -0.5,
             'Communications and Journalism': 0.75,
             'Art and Performance': -0.25, 'Agriculture': 1.25,
             'Social Sciences and History': 0.25, 'Business': -0.75,
             'Math and Statistics': 0.75, 'Architecture': -0.75,
             'Computer Science': 0.75, 'Engineering': -0.25}

# Load the data into a dataframe and us pd.melt to unpivot the degree column
df = pd.DataFrame(gender_degree_data)
df = pd.melt(df, id_vars='Year', var_name='Degree', value_name='conferred')
df['Degree'] = [d.replace('_', ' ').title() for d in df.Degree]

# Define a formatter that works for both bokeh and matplotlib
def percent_format(x):
    try:
        return '{:0.0f}%'.format(x)
    except:
        return '%d%' % x

# Define the value dimensions
vdim = hv.Dimension('conferred', range=(0, 90))

# Define the dataset
ds = hv.Dataset(df, vdims=vdim)
curves = ds.to(hv.Curve, 'Year', groupby='Degree').overlay().redim(Year=dict(range=(1970, 2030)))

# Define a function to get the text annotations
max_year = ds['Year'].max()
def offset(row):
    row['conferred'] += y_offsets.get(row.Degree, 0)
    return row
label_df = df[df.Year==max_year].apply(offset, axis=1)
labels = hv.Labels(label_df, ['Year', 'conferred'], 'Degree')

# %%
import holoviews as hv
import pandas as pd

# Assuming 'data' contains a 'gender' and 'split_frac' column, you can aggregate or use other relevant data
# For example, creating a sample dataframe for Bachelor Degrees by Gender (replace this with your data)

# Sample data (Replace with actual data)
data = pd.DataFrame({
    'gender': ['M', 'W', 'M', 'W', 'M', 'W'],
    'bachelor_degrees': [30, 45, 50, 65, 55, 70]
})

# Create a bar plot using holoviews
bars = hv.Bars(data, kdims=['gender'], vdims=['bachelor_degrees'])

# Display the plot
bars.opts(
    xlabel='Gender', ylabel='Bachelor Degrees',
    title='Bachelor Degrees by Gender', color='gender',
    width=600, height=400
)

# Show plot
hv.extension('bokeh')
bars
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='d7d200e5-f616-4add-bf97-16e4586683a7'>
#   <div id="e202fc42-ebdb-4e30-b603-bb4d83f2d977" data-root-id="d7d200e5-f616-4add-bf97-16e4586683a7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='79efb856-1fa2-415f-b63d-70f0fa681189'>
#   <div id="d15ca5bd-5123-4f8f-9426-33b3f50214cc" data-root-id="79efb856-1fa2-415f-b63d-70f0fa681189" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...
